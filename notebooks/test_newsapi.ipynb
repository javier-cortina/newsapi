# %%
import pandas as pd
import dagster as dg
from datetime import datetime, timedelta, timezone
import os
from pathlib import Path
from typing import Optional
from dotenv import load_dotenv
from eventregistry import EventRegistry, QueryArticlesIter, QueryItems

load_dotenv()
# Out:
# True

# %%
er = EventRegistry(apiKey=os.getenv("NEWSAPI_KEY"))

# %%
q = QueryArticlesIter(
	categoryUri=QueryItems.AND(["dmoz/Computers/Artificial_Intelligence", "dmoz/Business/Marketing_and_Advertising"]),
	lang="eng",
	dateStart=(datetime.now() - timedelta(days=7)).strftime("%Y-%m-%d")
)
articles = []
for article in q.execQuery(er, sortBy="date", maxItems=100):
	articles.append(article)

# %%
df = pd.DataFrame(articles)
df
# Out:
#                   uri lang  isDuplicate        date      time  \
# 0   2025-12-924368101  eng        False  2025-12-16  09:58:35
# 1   2025-12-924269998  eng        False  2025-12-16  08:08:00
# 2   2025-12-924264245  eng        False  2025-12-16  08:05:37
# 3   2025-12-924229348  eng        False  2025-12-16  07:24:49
# 4   2025-12-924131287  eng        False  2025-12-16  05:12:13
# ..                ...  ...          ...         ...       ...
# 95  2025-12-921088160  eng        False  2025-12-12  14:56:28
# 96  2025-12-921008233  eng        False  2025-12-12  13:36:55
# 97  2025-12-920993415  eng        False  2025-12-12  13:17:27
# 98  2025-12-920947399  eng        False  2025-12-12  12:38:00
# 99  2025-12-920942314  eng         True  2025-12-12  12:30:59
#
#                 dateTime           dateTimePub dataType       sim  \
# 0   2025-12-16T09:58:35Z  2025-12-16T09:33:00Z     news  0.000000
# 1   2025-12-16T08:08:00Z  2025-12-16T07:59:00Z     news  0.000000
# 2   2025-12-16T08:05:37Z  2025-12-16T07:43:04Z     news  0.000000
# 3   2025-12-16T07:24:49Z  2025-12-16T06:55:08Z     news  0.000000
# 4   2025-12-16T05:12:13Z  2025-12-16T05:00:11Z     news  0.000000
# ..                   ...                   ...      ...       ...
# 95  2025-12-12T14:56:28Z  2025-12-12T12:18:28Z     news  0.000000
# 96  2025-12-12T13:36:55Z  2025-12-12T13:33:45Z     news  0.780392
# 97  2025-12-12T13:17:27Z  2025-12-12T13:00:00Z     news  0.000000
# 98  2025-12-12T12:38:00Z  2025-12-12T12:27:25Z     news  0.764706
# 99  2025-12-12T12:30:59Z  2025-12-12T12:28:07Z     news  0.764706
#
#                                                   url  \
# 0   https://www.finextra.com/pressarticle/108334/s...
# 1   https://economictimes.indiatimes.com/news/comp...
# 2   https://www.chosun.com/english/industry-en/202...
# 3   https://roushada13.medium.com/when-brands-grow...
# 4   https://uk.themedialeader.com/the-brief-tuesda...
# ..                                                ...
# 95  https://www.mysmartprice.com/gear/appliances/a...
# 96  https://www.investing.com/news/analyst-ratings...
# 97  https://searchengineland.com/black-friday-llms...
# 98  https://www.investing.com/news/analyst-ratings...
# 99  https://za.investing.com/news/analyst-ratings/...
#
#                                                 title  \
# 0   Smartstream relocates North American HQ to Man...
# 1   Propagate India elevates Parikshit Bhattachary...
# 2   Rebellions Challenges NVIDIA in AI Inference M...
# 3   When Brands Grow a Personality: Inside the Ris...
# 4   The Brief - Tuesday 16 December - More scams f...
# ..                                                ...
# 95  Samsung Marks 30 Years in India With a New Inn...
# 96  Piper Sandler raises Broadcom stock price targ...
# 97  What Black Friday reveals about how LLMs under...
# 98  Broadcom stock price target maintained at $525...
# 99  Broadcom stock price target maintained at $525...
#
#                                                  body  \
# 0   This content is provided by an external author...
# 1   Propagate India has appointed Parikshit Bhatta...
# 2   South Korean AI Semiconductor Startup, Valued ...
# 3   The AIsh -- 16 december, 2025\n\nFor over a de...
# 4   ⌛ The US government appears poised to extend t...
# ..                                                ...
# 95  Samsung used its 30-year milestone in India to...
# 96  Investing.com - Piper Sandler has raised its p...
# 97  Analysis of 10,000 LLM responses reveals the d...
# 98  Investing.com - Cantor Fitzgerald maintained i...
# 99  Investing.com - Cantor Fitzgerald maintained i...
#
#                                                source  \
# 0   {'uri': 'finextra.com', 'dataType': 'news', 't...
# 1   {'uri': 'economictimes.indiatimes.com', 'dataT...
# 2   {'uri': 'chosun.com', 'dataType': 'news', 'tit...
# 3   {'uri': 'roushada13.medium.com', 'dataType': '...
# 4   {'uri': 'uk.themedialeader.com', 'dataType': '...
# ..                                                ...
# 95  {'uri': 'mysmartprice.com', 'dataType': 'news'...
# 96  {'uri': 'investing.com', 'dataType': 'news', '...
# 97  {'uri': 'searchengineland.com', 'dataType': 'n...
# 98  {'uri': 'investing.com', 'dataType': 'news', '...
# 99  {'uri': 'za.investing.com', 'dataType': 'news'...
#
#                                               authors  \
# 0   [{'uri': 'editorial_team@finextra.com', 'name'...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   [{'uri': 'ellie_hammonds@uk.themedialeader.com...
# ..                                                ...
# 95                                                 []
# 96                                                 []
# 97                                                 []
# 98                                                 []
# 99                                                 []
#
#                                                 image      eventUri  \
# 0    https://www.finextra.com/about/finextra-logo.png          None
# 1   https://img.etimg.com/thumb/msid-125999158,wid...          None
# 2   https://www.chosun.com/resizer/v2/MNSDAOBWHAYT...          None
# 3   https://miro.medium.com/v2/resize:fit:800/1*t4...          None
# 4   https://uk.themedialeader.com/wp-content/uploa...          None
# ..                                                ...           ...
# 95  https://www.mysmartprice.com/wp-content/upload...          None
# 96  https://i-invdn-com.investing.com/news/news_si...  eng-11225511
# 97  https://searchengineland.com/wp-content/seload...          None
# 98  https://i-invdn-com.investing.com/news/interna...  eng-11225511
# 99  https://i-invdn-com.investing.com/news/interna...          None
#
#     sentiment        wgt  relevance
# 0    0.317647  503575115          4
# 1    0.388235  503568480          3
# 2    0.121569  503568337          5
# 3    0.231373  503565889          6
# 4   -0.137255  503557933          2
# ..        ...        ...        ...
# 95   0.411765  503247388          4
# 96   0.231373  503242615          3
# 97   0.050980  503241447          4
# 98   0.176471  503239080          2
# 99   0.176471  503238659          2
#
# [100 rows x 19 columns]

# %%
# Add metadata columns
df["fetched_at"] = datetime.now()

# Map eventregistry fields to consistent schema
if "uri" in df.columns:
	df["article_id"] = df["uri"]
if "url" not in df.columns and "uri" in df.columns:
	df["url"] = df["uri"]
if "dateTime" in df.columns:
	df["publishedAt"] = pd.to_datetime(df["dateTime"])
elif "date" in df.columns:
	df["publishedAt"] = pd.to_datetime(df["date"])

# Handle source information
if "source" in df.columns:
	df["source_name"] = df["source"].apply(
		lambda x: x.get("title")
		if isinstance(x, dict)
		else str(x)
		if x
		else None
	)
	df["source_uri"] = df["source"].apply(
		lambda x: x.get("uri") if isinstance(x, dict) else None
	)

# %%
df
# Out:
#                   uri lang  isDuplicate        date      time  \
# 0   2025-12-924368101  eng        False  2025-12-16  09:58:35
# 1   2025-12-924269998  eng        False  2025-12-16  08:08:00
# ..        ...       ...                        ...                ...
# 95  503247388         4 2025-12-16 12:46:17.614966  2025-12-921088160
# 96  503242615         3 2025-12-16 12:46:17.614966  2025-12-921008233
# 97  503241447         4 2025-12-16 12:46:17.614966  2025-12-920993415
# 98  503239080         2 2025-12-16 12:46:17.614966  2025-12-920947399
# 99  503238659         2 2025-12-16 12:46:17.614966  2025-12-920942314
#
#                  publishedAt  \
# 0  2025-12-16 09:58:35+00:00
# 1  2025-12-16 08:08:00+00:00
# 2  2025-12-16 08:05:37+00:00
# 3  2025-12-16 07:24:49+00:00
# 4  2025-12-16 05:12:13+00:00
# ..                       ...
# 95 2025-12-12 14:56:28+00:00
# 96 2025-12-12 13:36:55+00:00
# 97 2025-12-12 13:17:27+00:00
# 98 2025-12-12 12:38:00+00:00
# 99 2025-12-12 12:30:59+00:00
#
#                                           source_name  \
# 0                                   Finextra Research
# 1                                      Economic Times
# 2                                          Chosun.com
# 3                                              Medium
# 4   The Media Leader - News analysis, opinion and ...
# ..                                                ...
# 95                                   MySmartPrice.com
# 96                                      Investing.com
# 97                                 Search Engine Land
# 98                                      Investing.com
# 99                         Investing.com South Africa
#
#                       source_uri
# 0                   finextra.com
# 1   economictimes.indiatimes.com
# 2                     chosun.com
# 3          roushada13.medium.com
# 4          uk.themedialeader.com
# ..                           ...
# 95              mysmartprice.com
# 96                 investing.com
# 97          searchengineland.com
# 98                 investing.com
# 99              za.investing.com
#
# [100 rows x 24 columns]

# %%
{
	"num_articles": len(df),
	"last_fetch_timestamp": dg.MetadataValue.timestamp(datetime.now(timezone.utc)),
	"preview": dg.MetadataValue.md(
		df[["title", "source_name", "publishedAt"]].head(5).to_markdown()
		if not df.empty
		and all(
			col in df.columns
			for col in ["title", "source_name", "publishedAt"]
		)
		else df.head(5).to_markdown()
		if not df.empty
		else "No articles"
	),
}
# Out:
# ---------------------------------------------------------------------------
# CheckError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 {
#       2 	"num_articles": len(df),
# ----> 3 	"last_fetch_timestamp": dg.MetadataValue.timestamp(datetime.now()),
#       4 	"preview": dg.MetadataValue.md(
#       5 		df[["title", "source_name", "publishedAt"]].head(5).to_markdown()
#       6 		if not df.empty
#       7 		and all(
#       8 			col in df.columns
#       9 			for col in ["title", "source_name", "publishedAt"]
#      10 		)
#      11 		else df.head(5).to_markdown()
#      12 		if not df.empty
#      13 		else "No articles"
#      14 	),
#      15 }
#
# File c:\Users\CortinJa\code\newsapi-dentsu\.venv\Lib\site-packages\dagster\_core\definitions\metadata\metadata_value.py:325, in MetadataValue.timestamp(value)
#     323 elif isinstance(value, datetime):
#     324     if value.tzinfo is None:
# --> 325         check.failed(
#     326             "Datetime values provided to MetadataValue.timestamp must have timezones, "
#     327             f"but {value.isoformat()} does not"
#     328         )
#     329     return TimestampMetadataValue(value.timestamp())
#     330 else:
#
# File c:\Users\CortinJa\code\newsapi-dentsu\.venv\Lib\site-packages\dagster_shared\check\functions.py:1712, in failed(desc)
#    1709 if not isinstance(desc, str):
#    1710     raise CheckError("desc argument must be a string")
# -> 1712 raise CheckError(f"Failure condition: {desc}")
#
# CheckError: Failure condition: Datetime values provided to MetadataValue.timestamp must have timezones, but 2025-12-16T12:46:52.676054 does not
